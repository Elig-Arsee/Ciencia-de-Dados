# %% [markdown]
# <a href="https://colab.research.google.com/github/Elig-Arsee/Ciencia-de-Dados/blob/main/TCC_Explorar_dados_R.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Instalando pacotes e carregando bibliotecas

# %%
# Passo 1: Carregar os pacotes que serão usados

install.packages("dplyr") 
install.packages("rstatix") 
install.packages("ggplot2")
install.packages("foreign")

# %%
#Passo 2: Chamar bibliotecas importadas
library(dplyr)
library(car)
library(rstatix)
library(ggplot2)
library(foreign)

# %% [markdown]
# #Importando arquivo CSV e visualizando dados

# %%
#Passo 3: chamar arquivo csv

dados2018 <- read.csv("/content/2018.04622.csv")

# %%
#Excluindo NA
dados2018<- na.omit(dados2018)

# %%
#Passo 4.1: Visualizando dados
View(dados2018)
# Out:
#      entrevistador A1_Nquest peso tempo_entrevista localidade
# 1     1372954210    1        1    12:56:00 AM      URBANO
# 2     1372954210    2        1    1:03:00 AM       URBANO
# 3     1372954210    3        1    12:52:00 AM      URBANO
# 4     1372954210    4        1    12:48:00 AM      URBANO
# 5     1372954210    5        1    12:54:00 AM      URBANO
# 6     1372954210    6        1    12:52:00 AM      URBANO
# 7     1372954210    7        1    12:39:00 AM      URBANO
# 8     1372954210    8        1    12:55:00 AM      URBANO
# 9     1372954210    9        1    1:04:00 AM       URBANO
# 10    1372954210   10        1    12:54:00 AM      URBANO
# 11    1372954210   11        1    12:44:00 AM      URBANO
# 12    1372954210   12        1    12:40:00 AM      URBANO
# 13    1372954210   13        1    12:39:00 AM      URBANO
# 14    1372954210   14        1    12:42:00 AM      URBANO
# 15     365899267   15        1    12:46:00 AM      URBANO
# ...

# %%
#Passo 4.2: Visualizando variáveis
glimpse(dados2018)
# Out:
# Rows: 2,506
# Columns: 290
# $ entrevistador                                                                                                                                                                                                                                                         <dbl> …
# $ A1_Nquest                                                                                                                                                                                                                                                             <int> …
# $ peso                                                                                                                                                                                                                                                                  <int> …
# ...

# %% [markdown]
# # Renomeando variáveis e excluindo colunas

# %%
#Excluir colunas 1 à 4 
dados2018<-dados2018[,-c(1:4, 6:8)]
head(dados2018)
# Out:
#   localidade D1A..Qual.é.a.sua.idade. D1A..Qual.é.a.sua.idade...faixas.
# 1 URBANO     41                       35 A 44
# 2 URBANO     23                       18 A 24
# 3 URBANO     21                       18 A 24
# 4 URBANO     39                       35 A 44
# 5 URBANO     64                       55 A 64
# 6 URBANO     45                       45 A 54
#   D2..Sexo  D3..Escolaridade
# 1 Feminino  Colegial incompleto (até 2ª série do ensino médio)
# 2 Masculino Colegial incompleto (até 2ª série do ensino médio)
# 3 Feminino  Colegial completo (3ª série do ensino médio)
# 4 Masculino Ginásio incompleto (até 7ª série ou 8º ano do ensino fu
# 5 Masculino Analfabeto/ Nunca frequentou escola
# 6 Feminino  Analfabeto/ Nunca frequentou escola
#   Ramo.de.atividade     Ramo.de.atividade.do.chefe.da.família Ocupação
# 1 Prestação de serviços Missing                               Patrão
# 2 Comércio              Missing                               Empregado
# ...

# %%
#Renomear variável sexo
dados2018 <- dados2018 %>% rename(D2_Sexo = D2..Sexo)

# %%
#Renomear variável escolaridade
dados2018 <- dados2018 %>% rename(D3_Escolaridade = D3..Escolaridade)

# %%
#Renomear variável Ramo de atividade
dados2018 <- dados2018 %>% rename(Ramo_Atividade = Ramo.de.atividade)

# %%
#Renomear variável Ocupação
dados2018 <- dados2018 %>% rename(Ocupacao = Ocupação)

# %%
#Renomear variável Q01. Quanto o(a) sr(a) se interessa por política?
dados2018 <- dados2018 %>% rename(Q1_Interesse_Politica = Q1..Quanto.o.a..sr.a..se.interessa.por.política..O.a..sr.a..diria.que.é.)

# %%
#Renomear variável E com qual intensidade o(a) sr(a) acompanha política na TV, no rádio, nos jornais ou na
#internet: Muita intensidade, alguma intensidade, pouca intensidade, ou não acompanha política?
dados2018 <- dados2018 %>% rename(Q1_Intensidade_Acompanha_Politica = Q2..E.com.qual.intensidade.o.a..sr.a..acompanha.política.na.TV..no.rádio..nos.jornais.ou.na.internet..Muita.intensidade..alguma.intensidade..pouca.intensidade..ou.não.acompanha.política.)

# %%
#Renomear variável Q03. O quanto o(a) sr(a) concorda com a seguinte afirmação: “Você entende sobre os
#problemas políticos mais importantes do país”. O(a) sr(a) diria que concorda totalmente,
#concorda em parte, nem concorda nem discorda, discorda em parte ou discorda totalmente?
dados2018 <- dados2018 %>% rename(Q3_Entende_Problemas_Politicos = Q3..O.quanto.o.a..sr.a..concorda.com.a.seguinte.afirmação...Você.entende.sobre.os.problemas.políticos.mais.importantes.do.país..)

# %%
#Renomear variável Q04. Vou ler mais algumas frases e gostaria que para cada uma delas o(a) sr(a) dissesse se
#concorda muito, concorda um pouco, nem concorda, nem discorda, discorda um pouco ou discorda muito.
dados2018 <- dados2018 %>% rename(Q4A_Opiniao_Compromisso_Politica = Q4A..Destas.frases..gostaria.que.o.a..sr.a..dissesse.se.concorda.ou.discorda..O.que.as.pessoas.chamam.de.compromisso.em.política.é..na.verdade..apenas.uma.forma.de.negociar.os.princípios.)
dados2018 <- dados2018 %>% rename(Q4B_Opiniao_Politicos_Importam = Q4B..Destas.frases..gostaria.que.o.a..sr.a..dissesse.se.concorda.ou.discorda..A.maior.parte.dos.políticos.não.se.importa.com.as.pessoas)
dados2018 <- dados2018 %>% rename(Q4C_Opiniao_Politicos_Confiaveis = Q4C..Destas.frases..gostaria.que.o.a..sr.a..dissesse.se.concorda.ou.discorda..A.maior.parte.dos.políticos.é.confiável.)
dados2018 <- dados2018 %>% rename(Q4D_Opiniao_Politicos_Problemas = Q4D..Destas.frases..gostaria.que.o.a..sr.a..dissesse.se.concorda.ou.discorda..Os.políticos.são.o.principal.problema.do.Brasil)
dados2018 <- dados2018 %>% rename(Q4E_Opiniao_Lider_Forte = Q4E..Destas.frases..gostaria.que.o.a..sr.a..dissesse.se.concorda.ou.discorda..Ter.um.líder.forte.no.governo.é.bom.para.o.Brasil.mesmo.que.o.líder.não.cumpra.as.regras.para.fazer.as.coisas)
dados2018 <- dados2018 %>% rename(Q4F_Opiniao_Povo_Decisoes = Q4F..Destas.frases..gostaria.que.o.a..sr.a..dissesse.se.concorda.ou.discorda..O.povo..e.não.os.políticos..deveria.tomar.as.decisões.políticas.mais.importantes)
dados2018 <- dados2018 %>% rename(Q4G_Opiniao_Politicos_Interesses = Q4G..Destas.frases..gostaria.que.o.a..sr.a..dissesse.se.concorda.ou.discorda..A.maior.parte.dos.políticos.se.preocupa.apenas.com.os.interesses.dos.ricos.e.poderosos)

# %%
#Renomear variável Q05. Agora, pensando sobre as minorias no Brasil, vou ler mais algumas frases e gostaria que para
#cada uma delas o(a) sr(a) dissesse se concorda muito, concorda um pouco, nem concorda, nem discorda, discorda um pouco ou discorda muito.
dados2018 <- dados2018 %>% rename(Q5A_Opiniao_Minorias_Costumes = Q5A..Pensando.sobre.as.minorias.no.Brasil..vou.ler.algumas.frases.e.gostaria.que.o.a..sr.a..dissesse.se.concorda.ou.discorda..As.minorias.deveriam.se.adaptar.aos.costumes.e.tradições.do.Brasil)
dados2018 <- dados2018 %>% rename(Q5B_Opiniao_Vontade_Maioria = Q5B..Pensando.sobre.as.minorias.no.Brasil..vou.ler.algumas.frases.e.gostaria.que.o.a..sr.a..dissesse.se.concorda.ou.discorda..A.vontade.da.maioria.deveria.sempre.prevalecer..mesmo.que.prejudique.os.direitos.das.minorias)
dados2018 <- dados2018 %>% rename(Q5C_Opiniao_Imigrantes_Economia = Q5C..Pensando.sobre.as.minorias.no.Brasil..vou.ler.algumas.frases.e.gostaria.que.o.a..sr.a..dissesse.se.concorda.ou.discorda..Em.geral.os.imigrantes.fazem.bem.à.economia.do.Brasil)
dados2018 <- dados2018 %>% rename(Q5D_Opiniao_Imigrantes_Prejudicam = Q5D..Pensando.sobre.as.minorias.no.Brasil..vou.ler.algumas.frases.e.gostaria.que.o.a..sr.a..dissesse.se.concorda.ou.discorda..Os.imigrantes.prejudicam.a.cultura.brasileira)
dados2018 <- dados2018 %>% rename(Q5E_Opiniao_Imigrantes_Criminalidade = Q5E..Pensando.sobre.as.minorias.no.Brasil..vou.ler.algumas.frases.e.gostaria.que.o.a..sr.a..dissesse.se.concorda.ou.discorda..Os.imigrantes.aumentam.as.taxas.de.criminalidade.no.Brasil)

# %%
##Renomear variável Q06. Algumas pessoas dizem que algumas coisas são importantes para uma pessoa ser considerada
#verdadeiramente brasileira. Outras dizem que não são importantes. O quanto você acha que é importante
#(LEIA FRASE) para ser considerado verdadeiramente brasileiro: muito importante, mais ou menos importante,
#pouco importante ou nada importante? 
dados2018 <- dados2018 %>% rename(Q6A_Opiniao_Nascer_Brasileiro = Q6A..O.quanto.você.acha.que.é.importante.ter.nascido.no.Brasil.para.ser.considerado.verdadeiramente.brasileiro.)
dados2018 <- dados2018 %>% rename(Q6B_Opiniao_Ser_Brasileiro = Q6B..O.quanto.você.acha.que.é.importante.ter.antepassados.brasileiros.para.ser.considerado.verdadeiramente.brasileiro.)
dados2018 <- dados2018 %>% rename(Q6C_Opiniao_Lingua_Brasileiro = Q6C..O.quanto.você.acha.que.é.importante.ser.capaz.de.falar.a.língua.portuguesa.para.ser.considerado.verdadeiramente.brasileiro.)
dados2018 <- dados2018 %>% rename(Q6D_Opiniao_Seguir_Costumes = Q6D..O.quanto.você.acha.que.é.importante.seguir.os.costumes.e.tradições.do.Brasil.para.ser.considerado.verdadeiramente.brasileiro.)

# %%
##Renomear variável Q07. O quanto você acha que a corrupção está generalizada no Brasil, como por exemplo, as
#propinas entre políticos: muito generalizada, bem generalizada, pouco generalizada ou você acha que isso
#dificilmente acontece?
dados2018 <- dados2018 %>% rename(Q7_Opiniao_Corrupção_Generalizada = Q7...O.quanto.você.acha.que.a.corrupção.está.generalizada.no.Brasil..como.por.exemplo..as.propinas.entre.políticos.)

# %%
##Renomear variável Q08. O quanto o(a) sr(a) concorda com a seguinte afirmação “O GOVERNO DEVERIA TOMAR
#MEDIDAS PARA REDUZIR AS DIFERENÇAS ENTRE OS NÍVEIS DE RENDA”. O(a) sr(a) diria que concorda totalmente,
#concorda em parte, nem concorda nem discorda, discorda em parte ou discorda totalmente?
dados2018 <- dados2018 %>% rename(Q8_Opiniao_Distribuicao_Renda = Q8..O.quanto.o.a..sr.a..concorda.com.a.seguinte.afirmação..O.governo.deveria.tomar.medidas.para.reduzir.as.diferenças.entre.os.níveis.de.renda..)

# %%
##Renomear variável Q09. Na sua opinião, de uma maneira geral o Governo do Presidente Michel Temer nos últimos 2
#anos foi ótimo, bom, ruim ou péssimo?
dados2018 <- dados2018 %>% rename(Q9_Opiniao_Governo_MichelTemer = Q9..Na.sua.opinião..de.uma.maneira.geral.o.Governo.do.Presidente.Michel.Temer.nos.últimos.2.anos.foi.ótimo..bom..ruim.ou.péssimo.)

# %%
##Renomear variável Q10a. Existe algum partido político que representa a maneira como o(a) sr(a) pensa?
dados2018 <- dados2018 %>% rename(Q10A_Opiniao_PartidoPolitico_Representa = Q10A..Existe.algum.partido.político.que.representa.a.maneira.como.o.a..sr.a..pensa...Espontânea.)
dados2018 <- dados2018 %>% rename(Q10B_Opiniao_PartidoPolitico_MelhorRepresenta = Q10B..Qual.partido.melhor.representa.a.maneira.como.o.a..sr.a..pensa...Espontânea.)

# %%
##Renomear variável Q11. O(A) sr(a) considera que a situação econômica atual do país está muito melhor, um pouco
#melhor, está igual, um pouco pior ou muito pior que nos últimos doze meses?
dados2018 <- dados2018 %>% rename(Q11_Opiniao_Situacao_Economica = Q11..O.A..sr.a..considera.que.a.situação.econômica.atual.do.país.está.muito.melhor..um.pouco.melhor..está.igual..um.pouco.pior.ou.muito.pior.que.nos.últimos.doze.meses.)

# %%
##Renomear variável Q12P1-a. O(a) sr(a) votou no primeiro turno nesta eleição?
dados2018 <- dados2018 %>% rename(Q12P1A_Votou_Turno1_2018 = Q12P1.A..O.a..sr.a..votou.no.primeiro.turno.nesta.eleição...Espontânea.)

# %%
##Renomear variável ### SOMENTE PARA QUEM VOTOU NO PRIMEIRO TURNO - CITOU CÓDIGO 1 “SIM”
#NA Q12P1A ### Q12P1-b. (DISCO 1) Em quem O(A) SR(A) votou para presidente no primeiro turno?
dados2018 <- dados2018 %>% rename(Q12P1B_EmQuemVotou_Turno1_Presidente_2018 = Q12P1.B..Em.quem.o.a..sr.a..votou.para.presidente.no.primeiro.turno.)

# %%
##Renomear variável Q12P2-a. O(A) sr(a) votou no segundo turno desta eleição?
dados2018 <- dados2018 %>% rename(Q12P2A_Votou_Turno2_2018 = Q12P2.A..O.A..sr.a..votou.no.segundo.turno.desta.eleição...Espontânea.)

# %%
##Renomear variável ### SOMENTE PARA QUEM VOTOU NO SEGUNDO TURNO - CITOU CÓDIGO 1 “SIM” NA
#Q12P2A ###Q12P2-b. Em quem O(A) SR(A) votou para presidente no SEGUNDO turno
dados2018 <- dados2018 %>% rename(Q12P2B_EmQuemVotou_Turno2_Presidente_2018 = Q12P2.B..Em.quem.o.a..sr.a..votou.para.presidente.no.segundo.turno.)

# %%
##Renomear variável #### SOMENTE PARA QUEM VOTOU NO PRIMEIRO TURNO - CITOU CÓDIGO 1 “SIM” NA Q12P1A ###
#Em quem o(a) sr(a) votou para governador no primeiro turno nessa eleição?
dados2018 <- dados2018 %>% rename(Q12G1A_EmQuemVotou_Turno1_Governador_2018 = Q12G_1A..Em.quem.o.a..sr.a..votou.para.governador.no.primeiro.turno.nessa.eleição.)

# %%
##Renomear variável ### PARA ENTREVISTADOS DOS ESTADOS DO AM, AP, DF, MG, MS, PA, RJ, RN, RS, RO,
##RR, SC, SP E SE E QUE VOTARAM NO SEGUNDO TURNO DA ELEIÇÃO CITOU CÓDIGO 1 “SIM” NA Q12P2A ###
dados2018 <- dados2018 %>% rename(Q12G2_EmQuemVotou_Turno2_Governador_2018 = Q12G.2..E.no.segundo.turno..em.quem.o.a..sr.a..votou.para.governador.nessa.eleição.)

# %%
##Renomear variável ### SOMENTE PARA QUEM VOTOU NO PRIMEIRO TURNO - CITOU CÓDIGO 1 “SIM” NA Q12P1A
### (Q12S1) (DISCO 3) Neste ano, foram eleitos DOIS SENADORES por estado. Em quem o(a) Sr(a)
#votou para a primeira vaga de SENADOR por/pelo [PROGRAMAÇÃO: MOSTRAR NOME DA UF] nessa eleição? (ESTIMULADA E ÚNICA)
dados2018 <- dados2018 %>% rename(Q12S1_EmQuemVotou_PrimeiraVaga_Senador_2018 = Q12S1..Neste.ano..foram.eleitos.dois.senadores.por.estado..Em.quem.o.a..sr.a..votou.para.a.primeira.vaga.de.Senador.nessa.eleição.)

# %%
##Renomear variável ### SOMENTE PARA QUEM VOTOU NO PRIMEIRO TURNO - CITOU CÓDIGO 1 “SIM” NA Q12P1A
### (Q12S2) (DISCO 3) E em quem o(a) sr(a) votou para a SEGUNDA VAGA de SENADOR por/pelo
#[PROGRAMAÇÃO: MOSTRAR NOME DA UF] nessa eleição?
dados2018 <- dados2018 %>% rename(Q12S2_EmQuemVotou_SegundaVaga_Senador_2018 = Q12S2..E.em.quem.o.a..sr.a..votou.para.a.segunda.vaga.de.Senador.nessa.eleição.)

# %%
#Renomear Variável ### SOMENTE PARA QUEM VOTOU NO PRIMEIRO TURNO - CITOU CÓDIGO 1 “SIM” NA Q12P1A
### (Q12CD) E em quem o(a) sr(a) votou para Deputado Federal? (ESPONTÂNEA E RU) ANOTE DA FORMA MAIS
#COMPLETA POSSÍVEL TODOS OS DADOS DO CANDIDATO QUE O ENTREVISTADO SOUBER COMO: NOME, APELIDO, PARTIDO, NÚMERO DO PARTIDO, CIDADE) 
dados2018 <- dados2018 %>% rename(Q12CD_EmQuemVotou_Deputado_Federal_2018 = Q12CD..E.em.quem.o.a..sr.a..votou.para.Deputado.Federal...Espontânea.)

# %%
#Renomear Variável 
### (Q12CD) E em quem o(a) sr(a) votou para Deputado Federal? (ESPONTÂNEA E RU) ANOTE DA FORMA MAIS
#COMPLETA POSSÍVEL TODOS OS DADOS DO CANDIDATO QUE O ENTREVISTADO SOUBER COMO: NOME, APELIDO, PARTIDO, NÚMERO DO PARTIDO, CIDADE)
dados2018 <- dados2018 %>% rename(Q12CD_RECODE_EmQuemVotou_Deputado_Federal_2018 = Q12CD_recode_2018.E.em.quem.o.a..sr.a..votou.para.Deputado.Federal...Espontânea.)

# %%
#Renomear Variável (Q12AL_DF) E em quem o(a) sr(a) votou para Deputado Distrital? (ESPONTÂNEA E RU – ANOTE
#DA FORMA MAIS COMPLETA POSSÍVEL TODOS OS DADOS DO CANDIDATO QUE O ENTREVISTADO SOUBER COMO: NOME, APELIDO,
#PARTIDO, NÚMERO DO PARTIDO, CIDADE)
dados2018 <- dados2018 %>% rename(Q12AL_EmQuemVotou_Deputado_Estadual_2018 = Q12AL..E.em.quem.o.a..sr.a..votou.para.Deputado.Estadual...Espontânea.)

# %%
#Renomear Variável (Q12AL_DF) E em quem o(a) sr(a) votou para Deputado Distrital? (ESPONTÂNEA E RU – ANOTE
#DA FORMA MAIS COMPLETA POSSÍVEL TODOS OS DADOS DO CANDIDATO QUE O ENTREVISTADO SOUBER COMO: NOME, APELIDO,
#PARTIDO, NÚMERO DO PARTIDO, CIDADE)
dados2018 <- dados2018 %>% rename(Q12AL_RECODE_EmQuemVotou_Deputado_Estadual_2018 = Q12AL_recode_2018.E.em.quem.o.a..sr.a..votou.para.Deputado.Estadual...Espontânea.)

# %%
#Renomear Variável Q13a. O(A) sr(a) votou no primeiro turno na eleição de 2014?
dados2018 <- dados2018 %>% rename(Q13A_Votou_Turno1_2014 = Q13A..O.A..sr.a..votou.no.primeiro.turno.na.eleição.de.2014.)

# %%
#Renomear Variável ### SOMENTE PARA QUEM VOTOU NO PRIMEIRO TURNO - CITOU CÓDIGO 1 “SIM” NA Q13A
### Q13b. (DISCO 4) Em quem O(A) SR(A) votou para PRESIDENTE no primeiro turno da eleição de 2014?
dados2018 <- dados2018 %>% rename(Q13B_EmQuemVotou_Turno1_Presidente_2014 = Q13B..Em.quem.o.a..sr.a..votou.para.presidente.no.primeiro.turno.da.eleição.de.2014.)

# %%
#Renomear Variável (Q13B-2) O(A) sr(a) votou no segundo turno na eleição para presidente de 2014?
dados2018 <- dados2018 %>% rename(Q13B2_Votou_Turno2_2014 = Q13B_2..O.A..sr.a..votou.no.segundo.turno.na.eleição.para.presidente.de.2014.)

# %%
#Renomear Variável### SOMENTE PARA QUEM VOTOU NO SEGUNDO TURNO - CITOU CÓDIGO 1 “SIM” NA Q13B2 ###
#(Q13B2A) E no segundo turno das eleições de 2014, em quem o(a) sr(a) votou para PRESIDENTE:
dados2018 <- dados2018 %>% rename(Q13B2A_EmQuemVotou_Turno2_2014 = Q13B2A..E.no.segundo.turno.das.eleições.de.2014..em.quem.o.a..sr.a..votou.para.presidente.)

# %%
#Renomear Variável ### SOMENTE PARA QUEM VOTOU NO PRIMEIRO TURNO - CITOU CÓDIGO 1 “SIM” NA Q13A
### (Q13G1) (DISCO 5) E para governador de/do [PROGRAMAÇÃO: MOSTRAR NOME DA UF], em quem o(a)
#sr(a) votou no primeiro turno em 2014?
dados2018 <- dados2018 %>% rename(Q13G1_EmQuemVotou_Turno1_Governador_2014 = Q13G1..E.para.governador..em.quem.o.a..sr.a..votou.no.primeiro.turno.em.2014.)

# %%
#Renomear Variável###PARA ENTREVISTADOS DOS ESTADOS RJ, PA, PB, DF, AC, RS, RN, MS, CE, GO, AM, RO, AP, RR
#QUE VOTARAM NO SEGUNDO TURNO DA ELEIÇÃO DE 2014 – CÓD. 1 EM Q13B2 ### Q13G2. E no segundo turno de 2014,
#em quem o(a) sr(a) votou para governador de/do [PROGRAMAÇÃO: MOSTRAR NOME DA UF]
dados2018 <- dados2018 %>% rename(Q13G2_EmQuemVotou_Turno2_Governador_2014 = Q13G2..E.no.segundo.turno.de.2014..em.quem.o.a..sr.a..votou.para.governador.)

# %%
#Renomear Variáveis ### SOMENTE PARA QUEM VOTOU NO PRIMEIRO TURNO - CITOU CÓDIGO 1 “SIM” NA Q13A Q13S.
#(DISCO 6) E para senador por/pelo [PROGRAMAÇÃO: MOSTRAR NOME DA UF], em quemo(a) sr(a) votou em 2014?
dados2018 <- dados2018 %>% rename(Q13S_EmQuemVotou_Senador_2014 = Q13S..E.para.senador..em.quem.o.a..sr.a..votou.em.2014.)

# %%
#Renomear variáveis ### SOMENTE PARA QUEM VOTOU NO PRIMEIRO TURNO - CITOU CÓDIGO 1 “SIM” NA Q13A
#Q13CD. E em quem o(a) sr(a) votou para deputado federal em 2014?
dados2018 <- dados2018 %>% rename(Q13CD_EmQuemVotou_Deputado_Federal_2014 = Q13CD..E.em.quem.o.a..sr.a..votou.para.Deputado.Federal.em.2014...Espontânea.)

# %%
#Renomear variáveis variáveis ### SOMENTE PARA QUEM VOTOU NO PRIMEIRO TURNO - CITOU CÓDIGO 1 “SIM” NA Q13A
#Q13CD. E em quem o(a) sr(a) votou para deputado federal em 2014?
dados2018 <- dados2018 %>% rename(Q13CD_RECODE_EmQuemVotou_Deputado_Federal_2014 = Q13CD_recode_2014.E.em.quem.o.a..sr.a..votou.para.Deputado.Federal.em.2014...Espontânea.)

# %%
#Renomear variáveis Q13AL- E em quem o(a) sr(a) votou para Deputado Estadual em 2014?
dados2018 <- dados2018 %>% rename(Q13AL_EmQuemVotou_Deputado_Estadual_2014 = Q13AL..E.em.quem.o.a..sr.a..votou.para.Deputado.Estadual.em.2014...Espontânea.)

# %%
#Renomear variáveis Q13AL- E em quem o(a) sr(a) votou para Deputado Estadual em 2014?
dados2018 <- dados2018 %>% rename(Q13AL_RECODE_EmQuemVotou_Deputado_Estadual_2014 = Q13AL_recode_2014.E.em.quem.o.a..sr.a..votou.para.Deputado.Estadual.em.2014...Espontânea.)

# %%
#Renomear variáveis Q14a .(CARTELA 1) Algumas pessoas dizem que faz uma grande diferença quem governa o Brasil.
#Outras pessoas dizem que não faz diferença quem governa o Brasil. Gostaria que o(a) sr(a) desse
#uma nota de 1 a 5 sendo que 1 significa que “NÃO faz nenhuma diferença quem governa o Brasil”, e
#o 5 que “faz uma grande diferença quem governa o Brasil”. Que nota de 1 a 5 o(a) sr(a) dá para
#representar sua opinião sobre isso? 
dados2018 <- dados2018 %>% rename(Q14A_Opiniao_Diferenca_Governo = Q14A..Gostaria.que.o.a..sr.a..desse.uma.nota.de.1.a.5..sendo.que.1.significa.que..não.faz.nenhuma.diferença.quem.governa.o.Brasil...e.o.5.que..faz.uma.grande.diferença.quem.governa.o.Brasil..)

# %%
#Renomear variáveis Q14b (CARTELA 2) Algumas pessoas dizem que o nosso voto influencia muito no que acontece no
#Brasil, outras dizem que o nosso voto NÃO influencia nada no que acontece no Brasil. Gostaria que
#o(a) sr(a) desse uma nota de 1 a 5, sendo que 1 significa que o nosso voto “NÃO influencia nada no
#que acontece no Brasil” e 5 significa que o nosso voto “influencia muito” no que acontece no Brasil.
#Que nota de 1 a 5 o(a) sr(a) dá para representar sua opinião sobre isso?
dados2018 <- dados2018 %>% rename(Q14B_Opiniao_Influencia_Voto = Q14B..Gostaria.que.o.a..sr.a..desse.uma.nota.de.1.a.5..sendo.que..1.significa.que.o.nosso.voto..não.influencia.nada.no.que.acontece.no.Brasil..e.5.significa.que.o.nosso.voto..influencia.muito..no.que.acontece.no.Brasil.)

# %%
dados2018 <- dados2018 %>% rename(Q15.1..Usando.uma.nota.de.0.a.10.para.indicar.o.quanto.o.a..sr.a..gosta.do.partido..sendo.que.zero.significa.que.o.a..sr.a..não.gosta.do.partido.de.jeito.nenhum.e.dez.que.o.a..sr.a..gosta.muito..PT = Q15.1_Nota_Partido_PT)

# %%
#Renomear variáveis Q15 (CARTELA 3) Agora gostaria de saber com mais detalhes o que O(A) SR(A) pensa SOBRE
#alguns partidos políticos. Por favor, use uma nota de 0 a 10 para indicar o quanto O(A) SR(A) gosta
#do partido que eu vou mencionar, sendo que zero significa que O(A) SR(A) NÃO gosta do partido de
#jeito nenhum e dez que O(A) SR(A) gosta muito. Quando eu falar o nome de um partido que O(A)
#SR(A) não conhece, apenas diga que não o conhece.
dados2018 <- dados2018 %>% rename(Q15.1_Nota_Partido_PT = Q15.1..Usando.uma.nota.de.0.a.10.para.indicar.o.quanto.o.a..sr.a..gosta.do.partido..sendo.que.zero.significa.que.o.a..sr.a..não.gosta.do.partido.de.jeito.nenhum.e.dez.que.o.a..sr.a..gosta.muito..PT)
dados2018 <- dados2018 %>% rename(Q15.2_Nota_Partido_MDB = Q15.2..Usando.uma.nota.de.0.a.10.para.indicar.o.quanto.o.a..sr.a..gosta.do.partido..sendo.que.zero.significa.que.o.a..sr.a..não.gosta.do.partido.de.jeito.nenhum.e.dez.que.o.a..sr.a..gosta.muito..MDB)
dados2018 <- dados2018 %>% rename(Q15.3_Nota_Partido_MDB = Q15.3..Usando.uma.nota.de.0.a.10.para.indicar.o.quanto.o.a..sr.a..gosta.do.partido..sendo.que.zero.significa.que.o.a..sr.a..não.gosta.do.partido.de.jeito.nenhum.e.dez.que.o.a..sr.a..gosta.muito..PDT)
dados2018 <- dados2018 %>% rename(Q15.4_Nota_Partido_PODE.PODEMOS = Q15.4..Usando.uma.nota.de.0.a.10.para.indicar.o.quanto.o.a..sr.a..gosta.do.partido..sendo.que.zero.significa.que.o.a..sr.a..não.gosta.do.partido.de.jeito.nenhum.e.dez.que.o.a..sr.a..gosta.muito..PODE..PODEMOS)
dados2018 <- dados2018 %>% rename(Q15.5_Nota_Partido_PSDB = Q15.5..Usando.uma.nota.de.0.a.10.para.indicar.o.quanto.o.a..sr.a..gosta.do.partido..sendo.que.zero.significa.que.o.a..sr.a..não.gosta.do.partido.de.jeito.nenhum.e.dez.que.o.a..sr.a..gosta.muito..PSDB)
dados2018 <- dados2018 %>% rename(Q15.6_Nota_Partido_REDE = Q15.6..Usando.uma.nota.de.0.a.10.para.indicar.o.quanto.o.a..sr.a..gosta.do.partido..sendo.que.zero.significa.que.o.a..sr.a..não.gosta.do.partido.de.jeito.nenhum.e.dez.que.o.a..sr.a..gosta.muito..REDE)
dados2018 <- dados2018 %>% rename(Q15.7_Nota_Partido_DEM = Q15.7..Usando.uma.nota.de.0.a.10.para.indicar.o.quanto.o.a..sr.a..gosta.do.partido..sendo.que.zero.significa.que.o.a..sr.a..não.gosta.do.partido.de.jeito.nenhum.e.dez.que.o.a..sr.a..gosta.muito..DEM)
dados2018 <- dados2018 %>% rename(Q15.8_Nota_Partido_PSOL = Q15.8..Usando.uma.nota.de.0.a.10.para.indicar.o.quanto.o.a..sr.a..gosta.do.partido..sendo.que.zero.significa.que.o.a..sr.a..não.gosta.do.partido.de.jeito.nenhum.e.dez.que.o.a..sr.a..gosta.muito..PSOL)
dados2018 <- dados2018 %>% rename(Q15.9_Nota_Partido_PATRI.PATRIOTA = Q15.9..Usando.uma.nota.de.0.a.10.para.indicar.o.quanto.o.a..sr.a..gosta.do.partido..sendo.que.zero.significa.que.o.a..sr.a..não.gosta.do.partido.de.jeito.nenhum.e.dez.que.o.a..sr.a..gosta.muito..PATRI..PATRIOTA)
dados2018 <- dados2018 %>% rename(Q15.10_Nota_Partido_DC = Q15.10..Usando.uma.nota.de.0.a.10.para.indicar.o.quanto.o.a..sr.a..gosta.do.partido..sendo.que.zero.significa.que.o.a..sr.a..não.gosta.do.partido.de.jeito.nenhum.e.dez.que.o.a..sr.a..gosta.muito..DC)
dados2018 <- dados2018 %>% rename(Q15.11_Nota_Partido_NOVO = Q15.11..Usando.uma.nota.de.0.a.10.para.indicar.o.quanto.o.a..sr.a..gosta.do.partido..sendo.que.zero.significa.que.o.a..sr.a..não.gosta.do.partido.de.jeito.nenhum.e.dez.que.o.a..sr.a..gosta.muito..NOVO)
dados2018 <- dados2018 %>% rename(Q15.12_Nota_Partido_PSL = Q15.12..Usando.uma.nota.de.0.a.10.para.indicar.o.quanto.o.a..sr.a..gosta.do.partido..sendo.que.zero.significa.que.o.a..sr.a..não.gosta.do.partido.de.jeito.nenhum.e.dez.que.o.a..sr.a..gosta.muito..PSL)
dados2018 <- dados2018 %>% rename(Q15.13_Nota_Partido_PPL = Q15.13..Usando.uma.nota.de.0.a.10.para.indicar.o.quanto.o.a..sr.a..gosta.do.partido..sendo.que.zero.significa.que.o.a..sr.a..não.gosta.do.partido.de.jeito.nenhum.e.dez.que.o.a..sr.a..gosta.muito..PPL)
dados2018 <- dados2018 %>% rename(Q15.14_Nota_Partido_PCdoB = Q15.14..Usando.uma.nota.de.0.a.10.para.indicar.o.quanto.o.a..sr.a..gosta.do.partido..sendo.que.zero.significa.que.o.a..sr.a..não.gosta.do.partido.de.jeito.nenhum.e.dez.que.o.a..sr.a..gosta.muito..PCdoB)
dados2018 <- dados2018 %>% rename(Q15.15_Nota_Partido_PSTU = Q15.15..Usando.uma.nota.de.0.a.10.para.indicar.o.quanto.o.a..sr.a..gosta.do.partido..sendo.que.zero.significa.que.o.a..sr.a..não.gosta.do.partido.de.jeito.nenhum.e.dez.que.o.a..sr.a..gosta.muito..PSTU)
dados2018 <- dados2018 %>% rename(Q15.16_Nota_Partido_PV = Q15.16..Usando.uma.nota.de.0.a.10.para.indicar.o.quanto.o.a..sr.a..gosta.do.partido..sendo.que.zero.significa.que.o.a..sr.a..não.gosta.do.partido.de.jeito.nenhum.e.dez.que.o.a..sr.a..gosta.muito..PV)
dados2018 <- dados2018 %>% rename(Q15.17_Nota_Partido_PSB = Q15.17..Usando.uma.nota.de.0.a.10.para.indicar.o.quanto.o.a..sr.a..gosta.do.partido..sendo.que.zero.significa.que.o.a..sr.a..não.gosta.do.partido.de.jeito.nenhum.e.dez.que.o.a..sr.a..gosta.muito..PSB)
dados2018 <- dados2018 %>% rename(Q15.18_Nota_Partido_PP = Q15.18..Usando.uma.nota.de.0.a.10.para.indicar.o.quanto.o.a..sr.a..gosta.do.partido..sendo.que.zero.significa.que.o.a..sr.a..não.gosta.do.partido.de.jeito.nenhum.e.dez.que.o.a..sr.a..gosta.muito..PP)
dados2018 <- dados2018 %>% rename(Q15.19_Nota_Partido_PR = Q15.19..Usando.uma.nota.de.0.a.10.para.indicar.o.quanto.o.a..sr.a..gosta.do.partido..sendo.que.zero.significa.que.o.a..sr.a..não.gosta.do.partido.de.jeito.nenhum.e.dez.que.o.a..sr.a..gosta.muito..PR)
dados2018 <- dados2018 %>% rename(Q15.20_Nota_Partido_PSD = Q15.20..Usando.uma.nota.de.0.a.10.para.indicar.o.quanto.o.a..sr.a..gosta.do.partido..sendo.que.zero.significa.que.o.a..sr.a..não.gosta.do.partido.de.jeito.nenhum.e.dez.que.o.a..sr.a..gosta.muito..PSD)
dados2018 <- dados2018 %>% rename(Q15.21_Nota_PRB = Q15.21..Usando.uma.nota.de.0.a.10.para.indicar.o.quanto.o.a..sr.a..gosta.do.partido..sendo.que.zero.significa.que.o.a..sr.a..não.gosta.do.partido.de.jeito.nenhum.e.dez.que.o.a..sr.a..gosta.muito..PRB)
dados2018 <- dados2018 %>% rename(Q15.22_Nota_PSC = Q15.22..Usando.uma.nota.de.0.a.10.para.indicar.o.quanto.o.a..sr.a..gosta.do.partido..sendo.que.zero.significa.que.o.a..sr.a..não.gosta.do.partido.de.jeito.nenhum.e.dez.que.o.a..sr.a..gosta.muito..PSC)
dados2018 <- dados2018 %>% rename(Q15.23_Nota_PTB = Q15.23..Usando.uma.nota.de.0.a.10.para.indicar.o.quanto.o.a..sr.a..gosta.do.partido..sendo.que.zero.significa.que.o.a..sr.a..não.gosta.do.partido.de.jeito.nenhum.e.dez.que.o.a..sr.a..gosta.muito..PTB)
dados2018 <- dados2018 %>% rename(Q15.24_Nota_Partido_PHS = Q15.24..Usando.uma.nota.de.0.a.10.para.indicar.o.quanto.o.a..sr.a..gosta.do.partido..sendo.que.zero.significa.que.o.a..sr.a..não.gosta.do.partido.de.jeito.nenhum.e.dez.que.o.a..sr.a..gosta.muito..PHS)
dados2018 <- dados2018 %>% rename(Q15.25_Nota_PROS = Q15.25..Usando.uma.nota.de.0.a.10.para.indicar.o.quanto.o.a..sr.a..gosta.do.partido..sendo.que.zero.significa.que.o.a..sr.a..não.gosta.do.partido.de.jeito.nenhum.e.dez.que.o.a..sr.a..gosta.muito..PROS)
dados2018 <- dados2018 %>% rename(Q15.26_Nota_Partido_AVANTE = Q15.26..Usando.uma.nota.de.0.a.10.para.indicar.o.quanto.o.a..sr.a..gosta.do.partido..sendo.que.zero.significa.que.o.a..sr.a..não.gosta.do.partido.de.jeito.nenhum.e.dez.que.o.a..sr.a..gosta.muito..AVANTE)

# %%
dados2018 <- dados2018 %>% rename(Q16.1..Agora.usando.as.mesmas.notas..gostaria.que.o.a..sr.a..dissesse.o.quanto.gosta.de.alguns.políticos.que.vou.mencionar..Ciro.Gomes = Q16.1_Nota_Politico_CiroGomes)
dados2018 <- dados2018 %>% rename(Q16.2..Agora.usando.as.mesmas.notas..gostaria.que.o.a..sr.a..dissesse.o.quanto.gosta.de.alguns.políticos.que.vou.mencionar..Manuela = Q16.2_Nota_Politico_Manuela)
dados2018 <- dados2018 %>% rename(Q16.3..Agora.usando.as.mesmas.notas..gostaria.que.o.a..sr.a..dissesse.o.quanto.gosta.de.alguns.políticos.que.vou.mencionar..Guilherme.Boulos = Q16.3_Nota_Politico_GuilhermeBoulos)

# %%
#Renomear Variável Q16. (CARTELA 3) Agora usando as mesmas notas, gostaria que o(a) sr(a) me dissesse o quanto
#gosta de alguns políticos que vou mencionar. Quero lembrar que, zero significa que o(a) sr(a) não gosta de jeito
#nenhum do político que vou mencionar e dez que o(a) sr(a) gosta muito. De novo, se o(a) sr(a) não conhecer o político
#que eu disser, diga apenas que não o conhece.

dados2018 <- dados2018 %>% rename(Q16.1_Nota_Politico_CiroGomes = Q16.1..Agora.usando.as.mesmas.notas..gostaria.que.o.a..sr.a..dissesse.o.quanto.gosta.de.alguns.políticos.que.vou.mencionar..Ciro.Gomes)
dados2018 <- dados2018 %>% rename(Q16.2_Nota_Politico_Manuela = Q16.2..Agora.usando.as.mesmas.notas..gostaria.que.o.a..sr.a..dissesse.o.quanto.gosta.de.alguns.políticos.que.vou.mencionar..Manuela)
dados2018 <- dados2018 %>% rename(Q16.3_Nota_Politico_GuilhermeBoulos = Q16.3..Agora.usando.as.mesmas.notas..gostaria.que.o.a..sr.a..dissesse.o.quanto.gosta.de.alguns.políticos.que.vou.mencionar..Guilherme.Boulos)
dados2018 <- dados2018 %>% rename(Q16.4_Nota_Politico_MarinaSilva = Q16.4..Agora.usando.as.mesmas.notas..gostaria.que.o.a..sr.a..dissesse.o.quanto.gosta.de.alguns.políticos.que.vou.mencionar..Marina.Silva)
dados2018 <- dados2018 %>% rename(Q16.5_Nota_Politico_FernandoHaddad = Q16.5..Agora.usando.as.mesmas.notas..gostaria.que.o.a..sr.a..dissesse.o.quanto.gosta.de.alguns.políticos.que.vou.mencionar..Fernando.Haddad)
dados2018 <- dados2018 %>% rename(Q16.6_Nota_Politico_HenriqueMeirelles = Q16.6..Agora.usando.as.mesmas.notas..gostaria.que.o.a..sr.a..dissesse.o.quanto.gosta.de.alguns.políticos.que.vou.mencionar..Henrique.Meirelles)
dados2018 <- dados2018 %>% rename(Q16.7_Nota_Politico_JairBolsonaro = Q16.7..Agora.usando.as.mesmas.notas..gostaria.que.o.a..sr.a..dissesse.o.quanto.gosta.de.alguns.políticos.que.vou.mencionar..Jair.Bolsonaro)
dados2018 <- dados2018 %>% rename(Q16.8_Nota_Politico_GeraldoAlckmin = Q16.8..Agora.usando.as.mesmas.notas..gostaria.que.o.a..sr.a..dissesse.o.quanto.gosta.de.alguns.políticos.que.vou.mencionar..Geraldo.Alckmin)
dados2018 <- dados2018 %>% rename(Q16.9_Nota_Politico_JoaoAmoedo = Q16.9..Agora.usando.as.mesmas.notas..gostaria.que.o.a..sr.a..dissesse.o.quanto.gosta.de.alguns.políticos.que.vou.mencionar..João.Amoêdo)
dados2018 <- dados2018 %>% rename(Q16.10_Nota_Politico_Lula = Q16.10..Agora.usando.as.mesmas.notas..gostaria.que.o.a..sr.a..dissesse.o.quanto.gosta.de.alguns.políticos.que.vou.mencionar..Lula)
dados2018 <- dados2018 %>% rename(Q16.11_Nota_Politico_AlvaroDias = Q16.11..Agora.usando.as.mesmas.notas..gostaria.que.o.a..sr.a..dissesse.o.quanto.gosta.de.alguns.políticos.que.vou.mencionar..Alvaro.Dias)
dados2018 <- dados2018 %>% rename(Q16.12_Nota_Politico_JoaoGoulartFilho = Q16.12..Agora.usando.as.mesmas.notas..gostaria.que.o.a..sr.a..dissesse.o.quanto.gosta.de.alguns.políticos.que.vou.mencionar..João.Goulart.Filho)
dados2018 <- dados2018 %>% rename(Q16.13_Nota_Politico_CaboDaciolo = Q16.13..Agora.usando.as.mesmas.notas..gostaria.que.o.a..sr.a..dissesse.o.quanto.gosta.de.alguns.políticos.que.vou.mencionar..Cabo.Daciolo)
dados2018 <- dados2018 %>% rename(Q16.14_Nota_Politico_RodrigoMaia = Q16.14..Agora.usando.as.mesmas.notas..gostaria.que.o.a..sr.a..dissesse.o.quanto.gosta.de.alguns.políticos.que.vou.mencionar..Rodrigo.Maia)
dados2018 <- dados2018 %>% rename(Q16.15_Nota_Politico_Eymael = Q16.15..Agora.usando.as.mesmas.notas..gostaria.que.o.a..sr.a..dissesse.o.quanto.gosta.de.alguns.políticos.que.vou.mencionar..Eymael)
dados2018 <- dados2018 %>% rename(Q16.16_Nota_Politico_Vera = Q16.16..Agora.usando.as.mesmas.notas..gostaria.que.o.a..sr.a..dissesse.o.quanto.gosta.de.alguns.políticos.que.vou.mencionar..Vera)
dados2018 <- dados2018 %>% rename(Q16.17_Nota_Politico_AecioNeves = Q16.17..Agora.usando.as.mesmas.notas..gostaria.que.o.a..sr.a..dissesse.o.quanto.gosta.de.alguns.políticos.que.vou.mencionar..Aécio.Neves)
dados2018 <- dados2018 %>% rename(Q16.18_Nota_Politico_DilmaRousseff = Q16.18..Agora.usando.as.mesmas.notas..gostaria.que.o.a..sr.a..dissesse.o.quanto.gosta.de.alguns.políticos.que.vou.mencionar..Dilma.Rousseff)
dados2018 <- dados2018 %>% rename(Q16.19_Nota_Politico_RomeroJuca = Q16.19..Agora.usando.as.mesmas.notas..gostaria.que.o.a..sr.a..dissesse.o.quanto.gosta.de.alguns.políticos.que.vou.mencionar..Romero.Jucá)
dados2018 <- dados2018 %>% rename(Q16.20_Nota_Politico_RenanCalheiros = Q16.20..Agora.usando.as.mesmas.notas..gostaria.que.o.a..sr.a..dissesse.o.quanto.gosta.de.alguns.políticos.que.vou.mencionar..Renan.Calheiros)
dados2018 <- dados2018 %>% rename(Q16.21_Nota_Politico_MichelTemer = Q16.21..Agora.usando.as.mesmas.notas..gostaria.que.o.a..sr.a..dissesse.o.quanto.gosta.de.alguns.políticos.que.vou.mencionar..Michel.Temer)

# %%
#Renomear Variável Q17 (CARTELA 4) Na política as pessoas falam muito de esquerda e de direita. Em uma escala onde
#zero significa esquerda e 10 significa direita, para cada partido que eu citar, gostaria que o(a) sr(a)
#usasse esta escala para dizer se ele é de esquerda ou de direita. Se eu falar o nome de um partido
#que O(A) SR(A) não conhece, apenas diga que não o conhece. COMO classificaria o 
dados2018 <- dados2018 %>% rename(Q17.1_Classifica_Esquerda_Direita_PT = Q17.1..Em.uma.escala.onde.zero.significa.esquerda.e.10.significa.direita..gostaria.que.o.a..sr.a..dissesse.se.ele.é.de.esquerda.ou.de.direita..Como.classificaria.o.PT.)
dados2018 <- dados2018 %>% rename(Q17.2_Classifica_Esquerda_Direita_MDB = Q17.2..Em.uma.escala.onde.zero.significa.esquerda.e.10.significa.direita..gostaria.que.o.a..sr.a..dissesse.se.ele.é.de.esquerda.ou.de.direita..Como.classificaria.o.MDB.)
dados2018 <- dados2018 %>% rename(Q17.3_Classifica_Esquerda_Direita_PDT = Q17.3..Em.uma.escala.onde.zero.significa.esquerda.e.10.significa.direita..gostaria.que.o.a..sr.a..dissesse.se.ele.é.de.esquerda.ou.de.direita..Como.classificaria.o.PDT.)
dados2018 <- dados2018 %>% rename(Q17.4_Classifica_Esquerda_Direita_PODE..PODEMOS = Q17.4..Em.uma.escala.onde.zero.significa.esquerda.e.10.significa.direita..gostaria.que.o.a..sr.a..dissesse.se.ele.é.de.esquerda.ou.de.direita..Como.classificaria.o.PODE..PODEMOS.)
dados2018 <- dados2018 %>% rename(Q17.5_Classifica_Esquerda_Direita_PSDB = Q17.5..Em.uma.escala.onde.zero.significa.esquerda.e.10.significa.direita..gostaria.que.o.a..sr.a..dissesse.se.ele.é.de.esquerda.ou.de.direita..Como.classificaria.o.PSDB.)
dados2018 <- dados2018 %>% rename(Q17.6_Classifica_Esquerda_Direita_REDE = Q17.6..Em.uma.escala.onde.zero.significa.esquerda.e.10.significa.direita..gostaria.que.o.a..sr.a..dissesse.se.ele.é.de.esquerda.ou.de.direita..Como.classificaria.o.REDE.)
dados2018 <- dados2018 %>% rename(Q17.7_Classifica_Esquerda_Direita_DEM = Q17.7..Em.uma.escala.onde.zero.significa.esquerda.e.10.significa.direita..gostaria.que.o.a..sr.a..dissesse.se.ele.é.de.esquerda.ou.de.direita..Como.classificaria.o.DEM.)
dados2018 <- dados2018 %>% rename(Q17.8_Classifica_Esquerda_Direita_PSOL = Q17.8..Em.uma.escala.onde.zero.significa.esquerda.e.10.significa.direita..gostaria.que.o.a..sr.a..dissesse.se.ele.é.de.esquerda.ou.de.direita..Como.classificaria.o.PSOL.)
dados2018 <- dados2018 %>% rename(Q17.9_Classifica_Esquerda_Direita_PATRI..PATRIOTA = Q17.9..Em.uma.escala.onde.zero.significa.esquerda.e.10.significa.direita..gostaria.que.o.a..sr.a..dissesse.se.ele.é.de.esquerda.ou.de.direita..Como.classificaria.o.PATRI..PATRIOTA.)
dados2018 <- dados2018 %>% rename(Q17.10_Classifica_Esquerda_Direita_DC = Q17.10..Em.uma.escala.onde.zero.significa.esquerda.e.10.significa.direita..gostaria.que.o.a..sr.a..dissesse.se.ele.é.de.esquerda.ou.de.direita..Como.classificaria.o.DC.)
dados2018 <- dados2018 %>% rename(Q17.11_Classifica_Esquerda_Direita_NOVO = Q17.11..Em.uma.escala.onde.zero.significa.esquerda.e.10.significa.direita..gostaria.que.o.a..sr.a..dissesse.se.ele.é.de.esquerda.ou.de.direita..Como.classificaria.o.NOVO.)
dados2018 <- dados2018 %>% rename(Q17.12_Classifica_Esquerda_Direita_PSL = Q17.12..Em.uma.escala.onde.zero.significa.esquerda.e.10.significa.direita..gostaria.que.o.a..sr.a..dissesse.se.ele.é.de.esquerda.ou.de.direita..Como.classificaria.o.PSL.)
dados2018 <- dados2018 %>% rename(Q17.13_Classifica_Esquerda_Direita_PPL = Q17.13..Em.uma.escala.onde.zero.significa.esquerda.e.10.significa.direita..gostaria.que.o.a..sr.a..dissesse.se.ele.é.de.esquerda.ou.de.direita..Como.classificaria.o.PPL.)
dados2018 <- dados2018 %>% rename(Q17.14_Classifica_Esquerda_Direita_PCdoB = Q17.14..Em.uma.escala.onde.zero.significa.esquerda.e.10.significa.direita..gostaria.que.o.a..sr.a..dissesse.se.ele.é.de.esquerda.ou.de.direita..Como.classificaria.o.PCdoB.)
dados2018 <- dados2018 %>% rename(Q17.15_Classifica_Esquerda_Direita_PSTUB = Q17.15..Em.uma.escala.onde.zero.significa.esquerda.e.10.significa.direita..gostaria.que.o.a..sr.a..dissesse.se.ele.é.de.esquerda.ou.de.direita..Como.classificaria.o.PSTU.)
dados2018 <- dados2018 %>% rename(Q17.16_Classifica_Esquerda_Direita_PV = Q17.16..Em.uma.escala.onde.zero.significa.esquerda.e.10.significa.direita..gostaria.que.o.a..sr.a..dissesse.se.ele.é.de.esquerda.ou.de.direita..Como.classificaria.o.PV.)
dados2018 <- dados2018 %>% rename(Q17.17_Classifica_Esquerda_Direita_PSB = Q17.17..Em.uma.escala.onde.zero.significa.esquerda.e.10.significa.direita..gostaria.que.o.a..sr.a..dissesse.se.ele.é.de.esquerda.ou.de.direita..Como.classificaria.o.PSB.)
dados2018 <- dados2018 %>% rename(Q17.18_Classifica_Esquerda_Direita_PP = Q17.18..Em.uma.escala.onde.zero.significa.esquerda.e.10.significa.direita..gostaria.que.o.a..sr.a..dissesse.se.ele.é.de.esquerda.ou.de.direita..Como.classificaria.o.PP.)
dados2018 <- dados2018 %>% rename(Q17.19_Classifica_Esquerda_Direita_PR = Q17.19..Em.uma.escala.onde.zero.significa.esquerda.e.10.significa.direita..gostaria.que.o.a..sr.a..dissesse.se.ele.é.de.esquerda.ou.de.direita..Como.classificaria.o.PR.)
dados2018 <- dados2018 %>% rename(Q17.20_Classifica_Esquerda_Direita_PSD = Q17.20..Em.uma.escala.onde.zero.significa.esquerda.e.10.significa.direita..gostaria.que.o.a..sr.a..dissesse.se.ele.é.de.esquerda.ou.de.direita..Como.classificaria.o.PSD.)
dados2018 <- dados2018 %>% rename(Q17.21_Classifica_Esquerda_Direita_PRB = Q17.21..Em.uma.escala.onde.zero.significa.esquerda.e.10.significa.direita..gostaria.que.o.a..sr.a..dissesse.se.ele.é.de.esquerda.ou.de.direita..Como.classificaria.o.PRB.)
dados2018 <- dados2018 %>% rename(Q17.22_Classifica_Esquerda_Direita_PSC = Q17.22..Em.uma.escala.onde.zero.significa.esquerda.e.10.significa.direita..gostaria.que.o.a..sr.a..dissesse.se.ele.é.de.esquerda.ou.de.direita..Como.classificaria.o.PSC.)
dados2018 <- dados2018 %>% rename(Q17.23_Classifica_Esquerda_Direita_PTB = Q17.23..Em.uma.escala.onde.zero.significa.esquerda.e.10.significa.direita..gostaria.que.o.a..sr.a..dissesse.se.ele.é.de.esquerda.ou.de.direita..Como.classificaria.o.PTB.)
dados2018 <- dados2018 %>% rename(Q17.24_Classifica_Esquerda_Direita_PHS = Q17.24..Em.uma.escala.onde.zero.significa.esquerda.e.10.significa.direita..gostaria.que.o.a..sr.a..dissesse.se.ele.é.de.esquerda.ou.de.direita..Como.classificaria.o.PHS.)
dados2018 <- dados2018 %>% rename(Q17.25_Classifica_Esquerda_Direita_PROS = Q17.25..Em.uma.escala.onde.zero.significa.esquerda.e.10.significa.direita..gostaria.que.o.a..sr.a..dissesse.se.ele.é.de.esquerda.ou.de.direita..Como.classificaria.o.PROS.)
dados2018 <- dados2018 %>% rename(Q17.26_Classifica_Esquerda_Direita_AVANTE = Q17.26..Em.uma.escala.onde.zero.significa.esquerda.e.10.significa.direita..gostaria.que.o.a..sr.a..dissesse.se.ele.é.de.esquerda.ou.de.direita..Como.classificaria.o.AVANTE.)

# %%
glimpse(dados2018)
# Out:
# Rows: 2,506
# Columns: 283
# $ localidade                                                                                                                                                                                                                                                            <chr> …
# $ D1A..Qual.é.a.sua.idade.                                                                                                                                                                                                                                              <int> …
# $ D1A..Qual.é.a.sua.idade...faixas.                                                                                                                                                                                                                                     <chr> …
# ...

# %%
colnames (dados2018) [col_Q15.1..Usando.uma.nota.de.0.a.10.para.indicar.o.quanto.o.a..sr.a..gosta.do.partido..sendo.que.zero.significa.que.o.a..sr.a..não.gosta.do.partido.de.jeito.nenhum.e.dez.que.o.a..sr.a..gosta.muito..PT] <- “Q15.1_Nota_Partido_PT”
# Out:
# Error in parse(text = x, srcfile = src): <text>:1:229: unexpected input
# 1: colnames (dados2018) [col_Q15.1..Usando.uma.nota.de.0.a.10.para.indicar.o.quanto.o.a..sr.a..gosta.do.partido..sendo.que.zero.significa.que.o.a..sr.a..não.gosta.do.partido.de.jeito.nenhum.e.de
#                                                                                                                                                                                                                                         ^
# Traceback:

# %%
#Renomear variável Ramo de atividade do chefe da família
dados2018 <- dados2018 %>% rename(Ramo_Atividade_Chefe_Familia = Ramo.de.atividade.do.chefe.da.família)

# %%
head(dados2018)
# Out:
#   localidade D3_Escolaridade
# 1 URBANO     Colegial incompleto (até 2ª série do ensino médio)
# 2 URBANO     Colegial incompleto (até 2ª série do ensino médio)
# 3 URBANO     Colegial completo (3ª série do ensino médio)
# 4 URBANO     Ginásio incompleto (até 7ª série ou 8º ano do ensino fu
# 5 URBANO     Analfabeto/ Nunca frequentou escola
# 6 URBANO     Analfabeto/ Nunca frequentou escola
#   Ramo_Atividade        Ramo_Atividade_Chefe_Familia Ocupação      ESTADOS
# 1 Prestação de serviços Missing                      Patrão        Acre
# 2 Comércio              Missing                      Empregado     Acre
# 3 Inativos              Missing                      Não aplicável Acre
# 4 Construção/ Outras    Missing                      Conta própria Acre
# 5 Agricultura           Missing                      Conta própria Acre
# 6 Atividade social      Missing                      Empregado     Acre
#   CIDADES    REGIÃO Q1_Interesse_Politica Q1_Intensidade_Acompanha_Politica ⋯
# ...
